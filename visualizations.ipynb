# %%
# from loader import ClothDataset
from loader import ClothDataset
import torch
import numpy as np
import torchvision
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision.transforms import Resize

# %%
trainset = ClothDataset(256, keys="train.pkl", domain_randomization=True)
rgb, depth, mask, label = trainset[50]
# Out:
# [ClothDataset] loaded 47400 keys from train.pkl
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-227256aa3788> in <module>
#       1 trainset = ClothDataset(256, keys="train.pkl", domain_randomization=True)
# ----> 2 rgb, depth, mask, label = trainset[50]
#
# ~/cloth-classification/loader.py in __getitem__(self, idx)
#     159                             view_mask = mask[view,:,:] # shape: 256 x 256
#     160
# --> 161                             view_rgb[:, ~view_mask] = img[:, ~view_mask]
#     162                             rgb[view,:,:,:] = view_rgb
#     163
#
# IndexError: The shape of the mask [256, 256] at index 0 does not match the shape of the indexed tensor [3, 267, 256] at index 1

# %%
print(rgb.shape)
# Out:
# torch.Size([4, 3, 256, 256])

# %%
new_rgb = rgb.detach().clone()[0,...]
# print(rgb[20:-40, 50:-50,...].shape)
new_rgb = (new_rgb - new_rgb.min())/(new_rgb.max() - new_rgb.min()) # reverse standardization
plt.imshow(new_rgb.permute(1, 2, 0)[20:-40, 50:-80,...])

# %%
new_rgb = rgb.detach().clone()[1,...]
new_rgb = (new_rgb - new_rgb.min())/(new_rgb.max() - new_rgb.min()) # reverse standardization
plt.imshow(new_rgb.permute(1, 2, 0))

# %%
new_rgb = rgb.detach().clone()[2,...]
new_rgb = (new_rgb - new_rgb.min())/(new_rgb.max() - new_rgb.min()) # reverse standardization
plt.imshow(new_rgb.permute(1, 2, 0))

# %%
new_rgb = rgb.detach().clone()[3,...]
new_rgb = (new_rgb - new_rgb.min())/(new_rgb.max() - new_rgb.min()) # reverse standardization
plt.imshow(new_rgb.permute(1, 2, 0))
